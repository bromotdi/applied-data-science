# %% [markdown]
# # Daria Bromot (FS500047)
#
# ## Seaborn Exercises

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. Later on in the Machine Learning section of the course, we will revisit this data, and use it to predict survival rates of passengers. For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# **Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!*

# %%
joint_plot = sns.jointplot(x='fare', y='age', data=titanic, xlim=(-100, 600), ylim=(-10, 90), edgecolor=None,
              color='b', height=7, ratio=3, space=0.2, s=20, marginal_kws=dict(edgecolor='gray', color='#b7c6df'))
joint_plot.ax_joint.yaxis.set_major_locator(plt.MultipleLocator(20))
plt.text(-165, 85, 'pearsonr = 0.096; p = 0.01', fontsize=10)
plt.show()

# %%
fig = plt.figure(figsize=(5, 3))

sns.distplot(titanic['fare'],bins=30,kde=False,color='red', hist_kws=dict(edgecolor='gray'))
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.xlabel('fare', fontsize=8)
plt.xlim(0, 600)
plt.ylim(0, 500)

plt.show()

# %%
fig = plt.figure(figsize=(5, 3))
sns.boxplot(x='class',y='age',data=titanic,palette='rainbow')
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()

# %%
fig = plt.figure(figsize=(4, 3))
swarm_plot = sns.swarmplot(x='class', y='age', data=titanic, palette='Set2', size=4)
plt.ylim(-10, 90)
plt.yticks(fontsize=8)
swarm_plot.axes.yaxis.set_major_locator(plt.MultipleLocator(20))
plt.show()
# Out:
# C:\Users\bromotdi\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
fig = plt.figure(figsize=(5, 3))
sns.countplot(x='sex', data=titanic, palette=['#5975a4', '#5f9e6e'])
plt.ylim(0, 600)
plt.yticks(fontsize=8)
plt.show()

# %%
fig = plt.figure(figsize=(5, 3))
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

g = sns.FacetGrid(data=titanic, col='sex')
plt.ylim(0, 120)
plt.xlim(0, 80)
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
g.map(plt.hist, 'age', edgecolor='#565656')


# Set x and y axis tick mark intervals to 10
g.axes[0,0].yaxis.set_major_locator(ticker.MultipleLocator(20))
g.axes[0,0].xaxis.set_major_locator(ticker.MultipleLocator(10))
g.axes[0,1].yaxis.set_major_locator(ticker.MultipleLocator(20))
g.axes[0,1].xaxis.set_major_locator(ticker.MultipleLocator(10))

plt.show()
